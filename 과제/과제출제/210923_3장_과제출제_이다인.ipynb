# %% [markdown]
# # PyTorch study_first week assignment
#
# ### Implement and train a linear regression model using PyTorch

# %% [markdown]
#  #-> 으로 표시된 부분과 = 뒤에 비워진 부분 채워주시면 됩니다 :)

# %% [markdown]
# <font color='green'> Load the necessary libraries </font>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import torch.nn.init as init
import matplotlib.pyplot as plt

# %% [markdown]
# <font color='green'> Data making </font>

# %%
# 갯수는 임의 지정
num_data = 1000
# Out:
# torch.Size([1000, 1])

# %%
# x는 -10에서 10까지의 숫자들이 무작위로 들어가게 균등하게 초기화
x = 
x.shape
# Out:
# torch.Size([1000, 1])

# %%
# 연산 그래프 정의 (연산을 통해 값이 초기화)
# y=2x+3

y =

# %%
# 노이즈 지정(mean = 디폴트 0, std = 0.2, init_normal이용하며 y와 같은 모양을 가져야함)
noise = 
noise.shape

# %%
# y에 노이즈를 더해주기
# 실제 데이터에서 노이즈가 추가되는 경우가 많음
y_noise =

# %% [markdown]
# <font color ='green'>Data visualization</font>

# %%
#데이터 시각화해보기
plt.figure(figsize = (10,10))
plt.scatter(x.numpy(),y.numpy(),s = 7, c = 'gray')
plt.axis([-12, 12, -25, 25])
plt.show()

# %% [markdown]
# <font color ='green'>Model</font>

# %%
# 입력 x = (1000, 1)
# y= (1000, 1) 즉, 특성의 갯수는 하나 Linear(x,y)
model = 

# 손실함수 지정
# 임의로 L1사용
loss_func = 

# 최적화 함수 지정
# 인수로 학습의 대상이 되는 모델의 변수 전달
# 학습률 임의로 지정(0.01)
optimizer =

# %% [markdown]
# Q. L1 loss와 MSE loss의 정의는?

# %% [markdown]
# <font color ='green'>Model Training</font>

# %%
# loss가 어떻게 변하는지 확인하기 위해 loss_arr을 만들어 기록
loss_arr = []

# target은 y
label = y

# 500번 학습
num_epoch = 1000

for i in range(num_epoch):
    
    # 이전 기울기 지우고 최적화 함수 초기화
    # 기울기를 지우지 않으면 학습이 잘 되지 않음(그때그때 구해야 함)
    optimizer.zero_grad()
    
    # 입력값 trian['x']를 모델에 넣어 결과값을 얻음
    # nn.Linear(1, 1)(x)
    output = 
    
    # 결과값과 목표값의 차이를 L1 손실 함수로 구해줌
    loss = 
    
    # 손실에 대한 기울기를 구함
    #->
    
    # 구한 기울기를 이용해 모델의 변수를 업데이트
    #->
    
    
    # 10번마다 모델의 변수가 어떻게 변하고 있는지 시각화
    if i % 10 == 0:
        
        plt.scatter(x.detach().numpy(), output.detach().numpy())
        plt.axis([-10, 10, -30, 30])
        plt.show()
        params = list(model.parameters())
        W = params[0].item()
        b = params[1].item()
        print('Epoch {:4d}/{} W: {:.3f}, b: {:.3f} Cost: {:.6f}'.format(
            i, num_epoch, W, b, loss))
    loss_arr.append(loss.detach().numpy())
# Out:
# Epoch    0/1000 W: 0.120, b: -0.909 Cost: 9.966801
# Epoch   10/1000 W: 0.356, b: -0.897 Cost: 8.842539
# Epoch   20/1000 W: 0.590, b: -0.884 Cost: 7.744922
# Epoch   30/1000 W: 0.819, b: -0.868 Cost: 6.690220
# Epoch   40/1000 W: 1.038, b: -0.850 Cost: 5.714705
# Epoch   50/1000 W: 1.240, b: -0.828 Cost: 4.873652
# Epoch   60/1000 W: 1.413, b: -0.800 Cost: 4.238307
# Epoch   70/1000 W: 1.536, b: -0.764 Cost: 3.880800
# Epoch   80/1000 W: 1.599, b: -0.721 Cost: 3.748821
# Epoch   90/1000 W: 1.623, b: -0.673 Cost: 3.687904
# Epoch  100/1000 W: 1.632, b: -0.624 Cost: 3.637701
# Epoch  110/1000 W: 1.639, b: -0.574 Cost: 3.587929
# Epoch  120/1000 W: 1.644, b: -0.525 Cost: 3.538187
# Epoch  130/1000 W: 1.649, b: -0.475 Cost: 3.488452
# Epoch  140/1000 W: 1.654, b: -0.425 Cost: 3.438716
# Epoch  150/1000 W: 1.660, b: -0.376 Cost: 3.388981
# Epoch  160/1000 W: 1.665, b: -0.326 Cost: 3.339245
# Epoch  170/1000 W: 1.670, b: -0.277 Cost: 3.289510
# Epoch  180/1000 W: 1.675, b: -0.227 Cost: 3.239775
# Epoch  190/1000 W: 1.680, b: -0.177 Cost: 3.190040
# Epoch  200/1000 W: 1.685, b: -0.128 Cost: 3.140304
# Epoch  210/1000 W: 1.690, b: -0.078 Cost: 3.090569
# Epoch  220/1000 W: 1.695, b: -0.029 Cost: 3.040834
# Epoch  230/1000 W: 1.700, b: 0.021 Cost: 2.991099
# Epoch  240/1000 W: 1.705, b: 0.071 Cost: 2.941364
# Epoch  250/1000 W: 1.710, b: 0.120 Cost: 2.891629
# Epoch  260/1000 W: 1.715, b: 0.170 Cost: 2.841894
# Epoch  270/1000 W: 1.720, b: 0.220 Cost: 2.792159
# Epoch  280/1000 W: 1.725, b: 0.269 Cost: 2.742424
# Epoch  290/1000 W: 1.730, b: 0.319 Cost: 2.692689
# Epoch  300/1000 W: 1.735, b: 0.368 Cost: 2.642953
# Epoch  310/1000 W: 1.740, b: 0.418 Cost: 2.593219
# Epoch  320/1000 W: 1.745, b: 0.468 Cost: 2.543483
# Epoch  330/1000 W: 1.750, b: 0.517 Cost: 2.493748
# Epoch  340/1000 W: 1.755, b: 0.567 Cost: 2.444013
# Epoch  350/1000 W: 1.760, b: 0.616 Cost: 2.394278
# Epoch  360/1000 W: 1.765, b: 0.666 Cost: 2.344543
# Epoch  370/1000 W: 1.770, b: 0.716 Cost: 2.294808
# Epoch  380/1000 W: 1.775, b: 0.765 Cost: 2.245073
# Epoch  390/1000 W: 1.780, b: 0.815 Cost: 2.195338
# Epoch  400/1000 W: 1.785, b: 0.865 Cost: 2.145602
# Epoch  410/1000 W: 1.790, b: 0.914 Cost: 2.095867
# Epoch  420/1000 W: 1.795, b: 0.964 Cost: 2.046132
# Epoch  430/1000 W: 1.800, b: 1.013 Cost: 1.996397
# Epoch  440/1000 W: 1.805, b: 1.063 Cost: 1.946663
# Epoch  450/1000 W: 1.810, b: 1.113 Cost: 1.896928
# Epoch  460/1000 W: 1.815, b: 1.162 Cost: 1.847194
# Epoch  470/1000 W: 1.820, b: 1.212 Cost: 1.797459
# Epoch  480/1000 W: 1.825, b: 1.261 Cost: 1.747725
# Epoch  490/1000 W: 1.830, b: 1.311 Cost: 1.697990
# Epoch  500/1000 W: 1.835, b: 1.361 Cost: 1.648255
# Epoch  510/1000 W: 1.840, b: 1.410 Cost: 1.598521
# Epoch  520/1000 W: 1.845, b: 1.460 Cost: 1.548787
# Epoch  530/1000 W: 1.850, b: 1.510 Cost: 1.499052
# Epoch  540/1000 W: 1.855, b: 1.559 Cost: 1.449317
# Epoch  550/1000 W: 1.860, b: 1.609 Cost: 1.399583
# Epoch  560/1000 W: 1.865, b: 1.658 Cost: 1.349849
# Epoch  570/1000 W: 1.870, b: 1.708 Cost: 1.300114
# Epoch  580/1000 W: 1.875, b: 1.758 Cost: 1.250380
# Epoch  590/1000 W: 1.880, b: 1.807 Cost: 1.200645
# Epoch  600/1000 W: 1.885, b: 1.857 Cost: 1.150910
# Epoch  610/1000 W: 1.890, b: 1.906 Cost: 1.101176
# Epoch  620/1000 W: 1.895, b: 1.956 Cost: 1.051442
# Epoch  630/1000 W: 1.900, b: 2.006 Cost: 1.001707
# Epoch  640/1000 W: 1.905, b: 2.055 Cost: 0.951971
# Epoch  650/1000 W: 1.910, b: 2.105 Cost: 0.902235
# Epoch  660/1000 W: 1.915, b: 2.155 Cost: 0.852500
# Epoch  670/1000 W: 1.920, b: 2.204 Cost: 0.802764
# Epoch  680/1000 W: 1.925, b: 2.254 Cost: 0.753028
# Epoch  690/1000 W: 1.930, b: 2.303 Cost: 0.703293
# Epoch  700/1000 W: 1.935, b: 2.353 Cost: 0.653557
# Epoch  710/1000 W: 1.940, b: 2.403 Cost: 0.603821
# Epoch  720/1000 W: 1.945, b: 2.452 Cost: 0.554086
# Epoch  730/1000 W: 1.950, b: 2.502 Cost: 0.504350
# Epoch  740/1000 W: 1.955, b: 2.551 Cost: 0.454614
# Epoch  750/1000 W: 1.960, b: 2.601 Cost: 0.404878
# Epoch  760/1000 W: 1.965, b: 2.651 Cost: 0.355143
# Epoch  770/1000 W: 1.970, b: 2.700 Cost: 0.305407
# Epoch  780/1000 W: 1.975, b: 2.750 Cost: 0.255671
# Epoch  790/1000 W: 1.980, b: 2.800 Cost: 0.205936
# Epoch  800/1000 W: 1.985, b: 2.849 Cost: 0.156204
# Epoch  810/1000 W: 1.990, b: 2.899 Cost: 0.106469
# Epoch  820/1000 W: 1.995, b: 2.948 Cost: 0.056734
# Epoch  830/1000 W: 2.014, b: 2.984 Cost: 0.051240
# Epoch  840/1000 W: 2.013, b: 2.990 Cost: 0.057655
# Epoch  850/1000 W: 2.013, b: 2.994 Cost: 0.058949
# Epoch  860/1000 W: 2.013, b: 2.997 Cost: 0.059363
# Epoch  870/1000 W: 2.013, b: 2.998 Cost: 0.059481
# Epoch  880/1000 W: 2.013, b: 2.999 Cost: 0.059474
# Epoch  890/1000 W: 2.013, b: 3.000 Cost: 0.059459
# Epoch  900/1000 W: 2.013, b: 3.000 Cost: 0.059458
# Epoch  910/1000 W: 2.013, b: 3.000 Cost: 0.059458
# Epoch  920/1000 W: 2.013, b: 3.000 Cost: 0.059459
# Epoch  930/1000 W: 2.013, b: 3.000 Cost: 0.059459
# Epoch  940/1000 W: 2.013, b: 3.000 Cost: 0.059459
# Epoch  950/1000 W: 2.013, b: 3.000 Cost: 0.059459
# Epoch  960/1000 W: 2.013, b: 3.000 Cost: 0.059459
# Epoch  970/1000 W: 2.013, b: 3.000 Cost: 0.059459
# Epoch  980/1000 W: 2.013, b: 3.000 Cost: 0.059459
# Epoch  990/1000 W: 2.013, b: 3.000 Cost: 0.059459

# %%
plt.figure(figsize=(15,15))
plt.scatter(x.numpy(),y.numpy(),c="blue")
plt.plot(x.detach().numpy(),output.detach().numpy(),c="red")
plt.axis([-10, 10, -30, 30])
plt.show()

# %% [markdown]
# <font color ='green'>Loss graph </font>

# %%
plt.plot(loss_arr)
plt.show()

# %% [markdown]
# 학습 후 모델 변수값 확인

# %%
#->
# W = [0], b = [1]
# Out:
# [Parameter containing:
#  tensor([[1.9881]], requires_grad=True), Parameter containing:
#  tensor([3.0000], requires_grad=True)]
