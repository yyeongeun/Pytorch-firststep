# %% [markdown]
# <8장>

# %% [markdown]
# 전이학습에 대해 설명하세요. </br>
# :

# %% [markdown]
# 스타일 트랜스퍼를 구현할 때 사용하는 최적화 알고리즘은? </br>
# :

# %% [markdown]
# **Model optimizer** </br>
# 아래는 전이학습을 사용하기 위한 코드 중 일부입니다. #에 맞는 코드를 채워주세요.

# %%
resnet = # pretain모델 resnet50을 불러와주세요.

# %%
# 아래 결과나오도록 코드를 작성해주세요.(ResNet 모델의 직속 자식 노드를 불러옴)
# Out:
# conv1
# bn1
# relu
# maxpool
# layer1
# layer2
# layer3
# layer4
# avgpool
# fc
