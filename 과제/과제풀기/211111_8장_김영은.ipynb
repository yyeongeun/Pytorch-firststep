# %% [markdown]
# # <8장>

# %% [markdown]
# **전이학습에 대해 설명하세요.** </br>
# : Transfer Learning </br>
# 특정 조건에서 얻어진 어떤 지식을 다른 상황에 맞게 말그대로 '전이'해서 활용하는 학습 방법입니다. </br>
# 특정 분야에서 학습된 신경망의 일부 능력을 유사하거나 전혀 새로운 분야에서 사용되는 신경망의 학습에 이용하는 것입니다.

# %% [markdown]
# **스타일 트랜스퍼를 구현할 때 사용하는 최적화 알고리즘은?** </br>
# : 2차 미분 값까지 이용한 L-BFGS 알고리즘 </br>
# 2차 미분값을 구할 때 연산 속도 면에서 1차 미분보다 느리기 때문에, 엄밀하게 계산하는 대신 근사하는 방법으로 바꿔서 연산 속도를 높인 방식이다.
# 여기에 최근 m개의 1차 미분 값만을 사용해서 더 적은 메모리를 사용하게 변형한 방법을 말한다.

# %% [markdown]
# **Model optimizer** </br>
# 아래는 전이학습을 사용하기 위한 코드 중 일부입니다. #에 맞는 코드를 채워주세요.

# %%
# pretain모델 resnet50을 불러와주세요.
resnet = models.resnet50(pretrained = True)

# %%
# 아래 결과나오도록 코드를 작성해주세요.(ResNet 모델의 직속 자식 노드를 불러옴)
for name,module in resnet.named_children():
    print(name)
# Out:
# conv1
# bn1
# relu
# maxpool
# layer1
# layer2
# layer3
# layer4
# avgpool
# fc
