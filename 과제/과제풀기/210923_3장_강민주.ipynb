# %% [markdown]
# # PyTorch study_first week assignment
#
# ### Implement and train a linear regression model using PyTorch

# %% [markdown]
#  #-> 으로 표시된 부분과 = 뒤에 비워진 부분 채워주시면 됩니다 :)

# %% [markdown]
# <font color='green'> Load the necessary libraries </font>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import torch.nn.init as init
import matplotlib.pyplot as plt

# %% [markdown]
# <font color='green'> Data making </font>

# %%
# 갯수는 임의 지정
num_data = 1000

# %%
# x는 -10에서 10까지의 숫자들이 무작위로 들어가게 균등하게 초기화
x = init.uniform_(torch.Tensor(num_data,1),-10,10)
x.shape
# Out:
# torch.Size([1000, 1])

# %%
# 연산 그래프 정의 (연산을 통해 값이 초기화)
# y=2x+3

y = 2*x +3

# %%
# 노이즈 지정(mean = 디폴트 0, std = 0.2, init_normal이용하며 y와 같은 모양을 가져야함)
noise = init.normal_(torch.FloatTensor(num_data,1),std=0.2)
noise.shape
# Out:
# torch.Size([1000, 1])

# %%
# y에 노이즈를 더해주기
# 실제 데이터에서 노이즈가 추가되는 경우가 많음
y_noise = y + noise

# %% [markdown]
# <font color ='green'>Data visualization</font>

# %%
#데이터 시각화해보기
plt.figure(figsize = (10,10))
plt.scatter(x.numpy(),y.numpy(),s = 7, c = 'gray')
plt.axis([-12, 12, -25, 25])
plt.show()

# %% [markdown]
# <font color ='green'>Model</font>

# %%
# 입력 x = (1000, 1)
# y= (1000, 1) 즉, 특성의 갯수는 하나 Linear(x,y)
model = nn.Linear(1,1)

# 손실함수 지정
# 임의로 L1사용
loss_func = nn.L1Loss()

# 최적화 함수 지정
# 인수로 학습의 대상이 되는 모델의 변수 전달
# 학습률 임의로 지정(0.01)
optimizer = optim.SGD(model.parameters(),lr=0.01)

# %% [markdown]
# Q. L1 loss와 MSE loss의 정의는?

# %% [markdown]
# <font color ='green'>Model Training</font>

# %%
# loss가 어떻게 변하는지 확인하기 위해 loss_arr을 만들어 기록
loss_arr = []

# target은 y
label = y

# 500번 학습
num_epoch = 1000

for i in range(num_epoch):
    
    # 이전 기울기 지우고 최적화 함수 초기화
    # 기울기를 지우지 않으면 학습이 잘 되지 않음(그때그때 구해야 함)
    optimizer.zero_grad()
    
    # 입력값 trian['x']를 모델에 넣어 결과값을 얻음
    # nn.Linear(1, 1)(x)
    output = model(x)
    
    # 결과값과 목표값의 차이를 L1 손실 함수로 구해줌
    loss = loss_func(output,label)
    
    # 손실에 대한 기울기를 구함
    loss.backward()
    
    # 구한 기울기를 이용해 모델의 변수를 업데이트
    optimizer.step()
    
    
    # 10번마다 모델의 변수가 어떻게 변하고 있는지 시각화
    if i % 10 == 0:
        
        plt.scatter(x.detach().numpy(), output.detach().numpy())
        plt.axis([-10, 10, -30, 30])
        plt.show()
        params = list(model.parameters())
        W = params[0].item()
        b = params[1].item()
        print('Epoch {:4d}/{} W: {:.3f}, b: {:.3f} Cost: {:.6f}'.format(
            i, num_epoch, W, b, loss))
    loss_arr.append(loss.detach().numpy())
# Out:
# Epoch    0/1000 W: 1.006, b: -0.472 Cost: 5.992750
# Epoch   10/1000 W: 1.428, b: -0.428 Cost: 4.145962
# Epoch   20/1000 W: 1.647, b: -0.352 Cost: 3.416595
# Epoch   30/1000 W: 1.674, b: -0.253 Cost: 3.306812
# Epoch   40/1000 W: 1.688, b: -0.153 Cost: 3.205017
# Epoch   50/1000 W: 1.701, b: -0.053 Cost: 3.103222
# Epoch   60/1000 W: 1.715, b: 0.047 Cost: 3.001428
# Epoch   70/1000 W: 1.728, b: 0.147 Cost: 2.899633
# Epoch   80/1000 W: 1.741, b: 0.247 Cost: 2.797838
# Epoch   90/1000 W: 1.755, b: 0.347 Cost: 2.696043
# Epoch  100/1000 W: 1.768, b: 0.447 Cost: 2.594249
# Epoch  110/1000 W: 1.782, b: 0.547 Cost: 2.492454
# Epoch  120/1000 W: 1.795, b: 0.647 Cost: 2.390660
# Epoch  130/1000 W: 1.808, b: 0.747 Cost: 2.288865
# Epoch  140/1000 W: 1.822, b: 0.847 Cost: 2.187070
# Epoch  150/1000 W: 1.835, b: 0.947 Cost: 2.085276
# Epoch  160/1000 W: 1.849, b: 1.047 Cost: 1.983481
# Epoch  170/1000 W: 1.862, b: 1.147 Cost: 1.881686
# Epoch  180/1000 W: 1.875, b: 1.247 Cost: 1.779892
# Epoch  190/1000 W: 1.889, b: 1.347 Cost: 1.678097
# Epoch  200/1000 W: 1.902, b: 1.447 Cost: 1.576303
# Epoch  210/1000 W: 1.916, b: 1.547 Cost: 1.474508
# Epoch  220/1000 W: 1.929, b: 1.647 Cost: 1.372713
# Epoch  230/1000 W: 1.942, b: 1.747 Cost: 1.270919
# Epoch  240/1000 W: 1.956, b: 1.847 Cost: 1.169124
# Epoch  250/1000 W: 1.969, b: 1.947 Cost: 1.067329
# Epoch  260/1000 W: 1.983, b: 2.047 Cost: 0.965535
# Epoch  270/1000 W: 1.996, b: 2.147 Cost: 0.863740
# Epoch  280/1000 W: 2.009, b: 2.247 Cost: 0.761946
# Epoch  290/1000 W: 2.023, b: 2.347 Cost: 0.660151
# Epoch  300/1000 W: 2.036, b: 2.447 Cost: 0.558356
# Epoch  310/1000 W: 2.045, b: 2.547 Cost: 0.456980
# Epoch  320/1000 W: 2.035, b: 2.644 Cost: 0.360720
# Epoch  330/1000 W: 2.026, b: 2.742 Cost: 0.264280
# Epoch  340/1000 W: 2.016, b: 2.840 Cost: 0.168482
# Epoch  350/1000 W: 2.009, b: 2.937 Cost: 0.071773
# Epoch  360/1000 W: 2.028, b: 2.962 Cost: 0.119088
# Epoch  370/1000 W: 2.027, b: 2.974 Cost: 0.124674
# Epoch  380/1000 W: 2.027, b: 2.982 Cost: 0.125469
# Epoch  390/1000 W: 2.027, b: 2.988 Cost: 0.124658
# Epoch  400/1000 W: 2.027, b: 2.992 Cost: 0.123947
# Epoch  410/1000 W: 2.027, b: 2.995 Cost: 0.124085
# Epoch  420/1000 W: 2.027, b: 2.996 Cost: 0.124082
# Epoch  430/1000 W: 2.027, b: 2.997 Cost: 0.123911
# Epoch  440/1000 W: 2.027, b: 2.998 Cost: 0.123866
# Epoch  450/1000 W: 2.027, b: 2.998 Cost: 0.123865
# Epoch  460/1000 W: 2.027, b: 2.999 Cost: 0.123859
# Epoch  470/1000 W: 2.027, b: 2.999 Cost: 0.123838
# Epoch  480/1000 W: 2.027, b: 3.000 Cost: 0.123835
# Epoch  490/1000 W: 2.027, b: 3.000 Cost: 0.123823
# Epoch  500/1000 W: 2.027, b: 3.000 Cost: 0.123814
# Epoch  510/1000 W: 2.027, b: 3.000 Cost: 0.123808
# Epoch  520/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  530/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  540/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  550/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  560/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  570/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  580/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  590/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  600/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  610/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  620/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  630/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  640/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  650/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  660/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  670/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  680/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  690/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  700/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  710/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  720/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  730/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  740/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  750/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  760/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  770/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  780/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  790/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  800/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  810/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  820/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  830/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  840/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  850/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  860/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  870/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  880/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  890/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  900/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  910/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  920/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  930/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  940/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  950/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  960/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  970/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  980/1000 W: 2.027, b: 3.000 Cost: 0.123807
# Epoch  990/1000 W: 2.027, b: 3.000 Cost: 0.123807

# %%
plt.figure(figsize=(15,15))
plt.scatter(x.numpy(),y.numpy(),c="blue")
plt.plot(x.detach().numpy(),output.detach().numpy(),c="red")
plt.axis([-10, 10, -30, 30])
plt.show()

# %% [markdown]
# <font color ='green'>Loss graph </font>

# %%
plt.plot(loss_arr)
plt.show()

# %% [markdown]
# 학습 후 모델 변수값 확인

# %%
list(model.parameters())
# W = [0], b = [1]
# Out:
# [Parameter containing:
#  tensor([[1.9758]], requires_grad=True),
#  Parameter containing:
#  tensor([2.9996], requires_grad=True)]
